# %%
import numpy as np
import scipy
import mne
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('TkAgg')

from Preprocessing import *
from Preprocessing_Acti import *

from TimeFreqAna import *
from Group_TF import *

# from GrangerCaus import *
# from Group_Gr import *

from SourcesReco import *
from Group_Src import *

### Preprocessing
### P1 ### PATRICIA JACQUET
# P1_S1_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P101_BSL.vhdr' ### 'PassiveCap_patients.txt'
# Preprocessing('P1_S1_D01_Bsl', P1_S1_D01_Bsl_raw)
# P1_S1_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P101_POST.vhdr'
# Preprocessing('P1_S1_D01_Pos', P1_S1_D01_Pos_raw)
# P1_S1_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_BSL_POS.vhdr' ### 'PassiveCap_patients.txt'
# Preprocessing('P1_S1_D10_Bsl', P1_S1_D10_Bsl_raw)
# P1_S1_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_POST_POS.vhdr' 
# Preprocessing('P1_S1_D10_Pos', P1_S1_D10_Pos_raw)
# P1_S2_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_2_BSL.vhdr' ### 'PassiveCap_patients_S2.txt'
# Preprocessing('P1_S2_D01_Bsl', P1_S2_D01_Bsl_raw)
# P1_S2_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_2_POS.vhdr'
# Preprocessing('P1_S2_D01_Pos', P1_S2_D01_Pos_raw)
# P1_S2_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_2_BSL_POS.vhdr' ### 'PassiveCap_patients_S2.txt'
# Preprocessing('P1_S2_D10_Bsl', P1_S2_D10_Bsl_raw)
# P1_S2_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P01_2_POS_2.vhdr'
# Preprocessing('P1_S2_D10_Pos', P1_S2_D10_Pos_raw)
# ## P2 ### GALLUCCI
# P2_S1_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_BSL_S1_tACS.vhdr' ### 'CACS-64_REF.bvef' if Iz / 'CACS-64_NO_REF.bvef' if FCz
# Preprocessing_Acti('P2_S1_D01_Bsl', P2_S1_D01_Bsl_raw)
# P2_S1_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_POS_S1_tACS.vhdr'
# Preprocessing_Acti('P2_S1_D01_Pos', P2_S1_D01_Pos_raw)
# P2_S1_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_BSL_S1_POS.vhdr' ### 'CACS-64_NO_REF.bvef'
# Preprocessing_Acti('P2_S1_D10_Bsl', P2_S1_D10_Bsl_raw)
# P2_S1_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_POS_S1_POS.vhdr'
# Preprocessing_Acti('P2_S1_D10_Pos', P2_S1_D10_Pos_raw)
# P2_S2_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_BSL_S2_PRE.vhdr' ### 'CACS-64_NO_REF.bvef'
# Preprocessing_Acti('P2_S2_D01_Bsl', P2_S2_D01_Bsl_raw)
# P2_S2_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_POS_S2_PRE.vhdr'
# Preprocessing_Acti('P2_S2_D01_Pos', P2_S2_D01_Pos_raw)
# P2_S2_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_BSL_S2_POS.vhdr' ### 'CACS-64_NO_REF.bvef'
# Preprocessing_Acti('P2_S2_D10_Bsl', P2_S2_D10_Bsl_raw)
# P2_S2_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P102_POS_S2_POS.vhdr'
# Preprocessing_Acti('P2_S2_D10_Pos', P2_S2_D10_Pos_raw)
## P3 ### DROP OUT GERMAN SION
# P3_S1_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P201_BSL_S1_PRE.vhdr' ### 'CACS-64_NO_REF.bvef' if FCz
# Preprocessing_Acti('P3_S1_D01_Bsl', P3_S1_D01_Bsl_raw)
# P3_S1_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P201_POS_S1_PRE.vhdr'
# Preprocessing_Acti('P3_S1_D01_Pos', P3_S1_D01_Pos_raw)
# P3_S1_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P201_BSL_S1_PST.vhdr' ### 'ActCap_Sion.bvef' F=1000Hz
# Preprocessing_Acti('P3_S1_D10_Bsl', P3_S1_D10_Bsl_raw)
# P3_S1_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P201_POS_S1_PST.vhdr' ### F=1000Hz
# Preprocessing_Acti('P3_S1_D10_Pos', P3_S1_D10_Pos_raw)
### P4 ### SWISS LADY SION --> EEG problem?
# P4_S1_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_1_1_BSL_PRE.vhdr' ### 'ActCap_Sion.bvef' if Iz / 'CACS-64_NO_REF.bvef' if FCz
# Preprocessing_Acti('P4_S1_D01_Bsl', P4_S1_D01_Bsl_raw)
# P4_S1_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_1_1_PST.vhdr'
# Preprocessing_Acti('P4_S1_D01_Pos', P4_S1_D01_Pos_raw)
# P4_S1_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_1_1_BSL_PST.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P4_S1_D10_Bsl', P4_S1_D10_Bsl_raw)
# P4_S1_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_1_1_POS_PST.vhdr'
# Preprocessing_Acti('P4_S1_D10_Pos', P4_S1_D10_Pos_raw)
# P4_S2_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_BSL_S2_PRE.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P4_S2_D01_Bsl', P4_S2_D01_Bsl_raw)
# P4_S2_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_POS_S2_PRE.vhdr'
# Preprocessing_Acti('P4_S2_D01_Pos', P4_S2_D01_Pos_raw)
# P4_S2_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_BDL_S2_PST_2.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P4_S2_D10_Bsl', P4_S2_D10_Bsl_raw)
# P4_S2_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P202_POS_S2_PST.vhdr'
# Preprocessing_Acti('P4_S2_D10_Pos', P4_S2_D10_Pos_raw)
### P5 ### RUDOLF
# P5_S1_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B1_S1_BSL.vhdr' ### 'ActCap_Sion.bvef' 
# Preprocessing_Acti('P5_S1_D01_Bsl', P5_S1_D01_Bsl_raw)
# P5_S1_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B1_S1_PST.vhdr'
# Preprocessing_Acti('P5_S1_D01_Pos', P5_S1_D01_Pos_raw)
# P5_S1_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B2_S1_BSL.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P5_S1_D10_Bsl', P5_S1_D10_Bsl_raw)
# P5_S1_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B2_S1_PST.vhdr'
# Preprocessing_Acti('P5_S1_D10_Pos', P5_S1_D10_Pos_raw)
# P5_S2_D01_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B1_S2_BSL.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P5_S2_D01_Bsl', P5_S2_D01_Bsl_raw)
# P5_S2_D01_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B1_S2_PST.vhdr'
# Preprocessing_Acti('P5_S2_D01_Pos', P5_S2_D01_Pos_raw)
# P5_S2_D10_Bsl_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B2_S2_BSL.vhdr' ### 'ActCap_Sion.bvef'
# Preprocessing_Acti('P5_S2_D10_Bsl', P5_S2_D10_Bsl_raw)
# P5_S2_D10_Pos_raw = '/home/robertofelipe_sg/Documents/EEG_Data/P103_B2_S2_PST.vhdr'
# Preprocessing_Acti('P5_S2_D10_Pos', P5_S2_D10_Pos_raw)

### Sources Time-Freq
## P1
# P1_S1_D01_Bsl_epx = mne.read_epochs('P1_S1_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P1_S1_D01_Bsl_epx, 'stim_cor', 'P1_S1_D01_Bsl', 0, 'tf_power')
# P1_S1_D01_Pos_epx = mne.read_epochs('P1_S1_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P1_S1_D01_Pos_epx, 'stim_cor', 'P1_S1_D01_Pos', 0, 'tf_power')
# P1_S1_D10_Bsl_epx = mne.read_epochs('P1_S1_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P1_S1_D10_Bsl_epx, 'stim_cor', 'P1_S1_D10_Bsl', 0, 'tf_power')
# P1_S1_D10_Pos_epx = mne.read_epochs('P1_S1_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P1_S1_D10_Pos_epx, 'stim_cor', 'P1_S1_D10_Pos', 0, 'tf_power')
# P1_S2_D01_Bsl_epx = mne.read_epochs('P1_S2_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P1_S2_D01_Bsl_epx, 'stim_cor', 'P1_S2_D01_Bsl', 0, 'tf_power')
# P1_S2_D01_Pos_epx = mne.read_epochs('P1_S2_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P1_S2_D01_Pos_epx, 'stim_cor', 'P1_S2_D01_Pos', 0, 'tf_power')
# P1_S2_D10_Bsl_epx = mne.read_epochs('P1_S2_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P1_S2_D10_Bsl_epx, 'stim_cor', 'P1_S2_D10_Bsl', 0, 'tf_power')
# P1_S2_D10_Pos_epx = mne.read_epochs('P1_S2_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P1_S2_D10_Pos_epx, 'stim_cor', 'P1_S2_D10_Pos', 0, 'tf_power')
# ## P2
# P2_S1_D01_Bsl_epx = mne.read_epochs('P2_S1_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P2_S1_D01_Bsl_epx, 'stim_cor', 'P2_S1_D01_Bsl', 0, 'tf_power')
# P2_S1_D01_Pos_epx = mne.read_epochs('P2_S1_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P2_S1_D01_Pos_epx, 'stim_cor', 'P2_S1_D01_Pos', 0, 'tf_power')
# P2_S1_D10_Bsl_epx = mne.read_epochs('P2_S1_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P2_S1_D10_Bsl_epx, 'stim_cor', 'P2_S1_D10_Bsl', 0, 'tf_power')
# P2_S1_D10_Pos_epx = mne.read_epochs('P2_S1_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P2_S1_D10_Pos_epx, 'stim_cor', 'P2_S1_D10_Pos', 0, 'tf_power')
# P2_S2_D01_Bsl_epx = mne.read_epochs('P2_S2_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P2_S2_D01_Bsl_epx, 'stim_cor', 'P2_S2_D01_Bsl', 0, 'tf_power')
# P2_S2_D01_Pos_epx = mne.read_epochs('P2_S2_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P2_S2_D01_Pos_epx, 'stim_cor', 'P2_S2_D01_Pos', 0, 'tf_power')
# P2_S2_D10_Bsl_epx = mne.read_epochs('P2_S2_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P2_S2_D10_Bsl_epx, 'stim_cor', 'P2_S2_D10_Bsl', 0, 'tf_power')
# P2_S2_D10_Pos_epx = mne.read_epochs('P2_S2_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P2_S2_D10_Pos_epx, 'stim_cor', 'P2_S2_D10_Pos', 0, 'tf_power')
# ## P3
# P3_S1_D01_Bsl_epx = mne.read_epochs('P3_S1_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P3_S1_D01_Bsl_epx, 'stim_cor', 'P3_S1_D01_Bsl', 0, 'tf_power')
# P3_S1_D01_Pos_epx = mne.read_epochs('P3_S1_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P3_S1_D01_Pos_epx, 'stim_cor', 'P3_S1_D01_Pos', 0, 'tf_power')
# P3_S1_D10_Bsl_epx = mne.read_epochs('P3_S1_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P3_S1_D10_Bsl_epx, 'stim_cor', 'P3_S1_D10_Bsl', 0, 'tf_power')
# P3_S1_D10_Pos_epx = mne.read_epochs('P3_S1_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P3_S1_D10_Pos_epx, 'stim_cor', 'P3_S1_D10_Pos', 0, 'tf_power')
# ## P4
# P4_S1_D01_Bsl_epx = mne.read_epochs('P4_S1_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P4_S1_D01_Bsl_epx, 'stim_cor', 'P4_S1_D01_Bsl', 0, 'tf_power')
# P4_S1_D01_Pos_epx = mne.read_epochs('P4_S1_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P4_S1_D01_Pos_epx, 'stim_cor', 'P4_S1_D01_Pos', 0, 'tf_power')
# P4_S1_D10_Bsl_epx = mne.read_epochs('P4_S1_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P4_S1_D10_Bsl_epx, 'stim_cor', 'P4_S1_D10_Bsl', 0, 'tf_power')
# P4_S1_D10_Pos_epx = mne.read_epochs('P4_S1_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P4_S1_D10_Pos_epx, 'stim_cor', 'P4_S1_D10_Pos', 0, 'tf_power')
# P4_S2_D01_Bsl_epx = mne.read_epochs('P4_S2_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P4_S2_D01_Bsl_epx, 'stim_cor', 'P4_S2_D01_Bsl', 0, 'tf_power')
# P4_S2_D01_Pos_epx = mne.read_epochs('P4_S2_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P4_S2_D01_Pos_epx, 'stim_cor', 'P4_S2_D01_Pos', 0, 'tf_power')
# P4_S2_D10_Bsl_epx = mne.read_epochs('P4_S2_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P4_S2_D10_Bsl_epx, 'stim_cor', 'P4_S2_D10_Bsl', 0, 'tf_power')
# P4_S2_D10_Pos_epx = mne.read_epochs('P4_S2_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P4_S2_D10_Pos_epx, 'stim_cor', 'P4_S2_D10_Pos', 0, 'tf_power')
# ## P5
# P5_S1_D01_Bsl_epx = mne.read_epochs('P5_S1_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P5_S1_D01_Bsl_epx, 'stim_cor', 'P5_S1_D01_Bsl', 0, 'tf_power')
# P5_S1_D01_Pos_epx = mne.read_epochs('P5_S1_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P5_S1_D01_Pos_epx, 'stim_cor', 'P5_S1_D01_Pos', 0, 'tf_power')
# P5_S1_D10_Bsl_epx = mne.read_epochs('P5_S1_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P5_S1_D10_Bsl_epx, 'stim_cor', 'P5_S1_D10_Bsl', 0, 'tf_power')
# P5_S1_D10_Pos_epx = mne.read_epochs('P5_S1_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P5_S1_D10_Pos_epx, 'stim_cor', 'P5_S1_D10_Pos', 0, 'tf_power')
# P5_S2_D01_Bsl_epx = mne.read_epochs('P5_S2_D01_Bsl_preprocessed_epo.fif')
# SourcesReco(P5_S2_D01_Bsl_epx, 'stim_cor', 'P5_S2_D01_Bsl', 0, 'tf_power')
# P5_S2_D01_Pos_epx = mne.read_epochs('P5_S2_D01_Pos_preprocessed_epo.fif')
# SourcesReco(P5_S2_D01_Pos_epx, 'stim_cor', 'P5_S2_D01_Pos', 0, 'tf_power')
# P5_S2_D10_Bsl_epx = mne.read_epochs('P5_S2_D10_Bsl_preprocessed_epo.fif')
# SourcesReco(P5_S2_D10_Bsl_epx, 'stim_cor', 'P5_S2_D10_Bsl', 0, 'tf_power')
# P5_S2_D10_Pos_epx = mne.read_epochs('P5_S2_D10_Pos_preprocessed_epo.fif')
# SourcesReco(P5_S2_D10_Pos_epx, 'stim_cor', 'P5_S2_D10_Pos', 0, 'tf_power')

### Sources Connectivity
## P1
P1_S1_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S1_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P1_S1_D01_Bsl_epx, 'stim_cor', 'P1_S1_D01_Bsl', 0, 'connect')
P1_S1_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S1_D01_Pos_preprocessed_epo.fif')
SourcesReco(P1_S1_D01_Pos_epx, 'stim_cor', 'P1_S1_D01_Pos', 0, 'connect')
P1_S1_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S1_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P1_S1_D10_Bsl_epx, 'stim_cor', 'P1_S1_D10_Bsl', 0, 'connect')
P1_S1_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S1_D10_Pos_preprocessed_epo.fif')
SourcesReco(P1_S1_D10_Pos_epx, 'stim_cor', 'P1_S1_D10_Pos', 0, 'connect')
P1_S2_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S2_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P1_S2_D01_Bsl_epx, 'stim_cor', 'P1_S2_D01_Bsl', 0, 'connect')
P1_S2_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S2_D01_Pos_preprocessed_epo.fif')
SourcesReco(P1_S2_D01_Pos_epx, 'stim_cor', 'P1_S2_D01_Pos', 0, 'connect')
P1_S2_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S2_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P1_S2_D10_Bsl_epx, 'stim_cor', 'P1_S2_D10_Bsl', 0, 'connect')
P1_S2_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P1_S2_D10_Pos_preprocessed_epo.fif')
SourcesReco(P1_S2_D10_Pos_epx, 'stim_cor', 'P1_S2_D10_Pos', 0, 'connect')
## P2
P2_S1_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S1_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P2_S1_D01_Bsl_epx, 'stim_cor', 'P2_S1_D01_Bsl', 0, 'connect')
P2_S1_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S1_D01_Pos_preprocessed_epo.fif')
SourcesReco(P2_S1_D01_Pos_epx, 'stim_cor', 'P2_S1_D01_Pos', 0, 'connect')
P2_S1_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S1_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P2_S1_D10_Bsl_epx, 'stim_cor', 'P2_S1_D10_Bsl', 0, 'connect')
P2_S1_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S1_D10_Pos_preprocessed_epo.fif')
SourcesReco(P2_S1_D10_Pos_epx, 'stim_cor', 'P2_S1_D10_Pos', 0, 'connect')
P2_S2_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S2_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P2_S2_D01_Bsl_epx, 'stim_cor', 'P2_S2_D01_Bsl', 0, 'connect')
P2_S2_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S2_D01_Pos_preprocessed_epo.fif')
SourcesReco(P2_S2_D01_Pos_epx, 'stim_cor', 'P2_S2_D01_Pos', 0, 'connect')
P2_S2_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S2_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P2_S2_D10_Bsl_epx, 'stim_cor', 'P2_S2_D10_Bsl', 0, 'connect')
P2_S2_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P2_S2_D10_Pos_preprocessed_epo.fif')
SourcesReco(P2_S2_D10_Pos_epx, 'stim_cor', 'P2_S2_D10_Pos', 0, 'connect')
## P3
P3_S1_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P3_S1_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P3_S1_D01_Bsl_epx, 'stim_cor', 'P3_S1_D01_Bsl', 0, 'connect')
P3_S1_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P3_S1_D01_Pos_preprocessed_epo.fif')
SourcesReco(P3_S1_D01_Pos_epx, 'stim_cor', 'P3_S1_D01_Pos', 0, 'connect')
P3_S1_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P3_S1_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P3_S1_D10_Bsl_epx, 'stim_cor', 'P3_S1_D10_Bsl', 0, 'connect')
P3_S1_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P3_S1_D10_Pos_preprocessed_epo.fif')
SourcesReco(P3_S1_D10_Pos_epx, 'stim_cor', 'P3_S1_D10_Pos', 0, 'connect')
## P4
P4_S1_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S1_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P4_S1_D01_Bsl_epx, 'stim_cor', 'P4_S1_D01_Bsl', 0, 'connect')
P4_S1_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S1_D01_Pos_preprocessed_epo.fif')
SourcesReco(P4_S1_D01_Pos_epx, 'stim_cor', 'P4_S1_D01_Pos', 0, 'connect')
P4_S1_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S1_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P4_S1_D10_Bsl_epx, 'stim_cor', 'P4_S1_D10_Bsl', 0, 'connect')
P4_S1_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S1_D10_Pos_preprocessed_epo.fif')
SourcesReco(P4_S1_D10_Pos_epx, 'stim_cor', 'P4_S1_D10_Pos', 0, 'connect')
P4_S2_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S2_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P4_S2_D01_Bsl_epx, 'stim_cor', 'P4_S2_D01_Bsl', 0, 'connect')
P4_S2_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S2_D01_Pos_preprocessed_epo.fif')
SourcesReco(P4_S2_D01_Pos_epx, 'stim_cor', 'P4_S2_D01_Pos', 0, 'connect')
P4_S2_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S2_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P4_S2_D10_Bsl_epx, 'stim_cor', 'P4_S2_D10_Bsl', 0, 'connect')
P4_S2_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P4_S2_D10_Pos_preprocessed_epo.fif')
SourcesReco(P4_S2_D10_Pos_epx, 'stim_cor', 'P4_S2_D10_Pos', 0, 'connect')
## P5
P5_S1_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S1_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P5_S1_D01_Bsl_epx, 'stim_cor', 'P5_S1_D01_Bsl', 0, 'connect')
P5_S1_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S1_D01_Pos_preprocessed_epo.fif')
SourcesReco(P5_S1_D01_Pos_epx, 'stim_cor', 'P5_S1_D01_Pos', 0, 'connect')
P5_S1_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S1_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P5_S1_D10_Bsl_epx, 'stim_cor', 'P5_S1_D10_Bsl', 0, 'connect')
P5_S1_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S1_D10_Pos_preprocessed_epo.fif')
SourcesReco(P5_S1_D10_Pos_epx, 'stim_cor', 'P5_S1_D10_Pos', 0, 'connect')
P5_S2_D01_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S2_D01_Bsl_preprocessed_epo.fif')
SourcesReco(P5_S2_D01_Bsl_epx, 'stim_cor', 'P5_S2_D01_Bsl', 0, 'connect')
P5_S2_D01_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S2_D01_Pos_preprocessed_epo.fif')
SourcesReco(P5_S2_D01_Pos_epx, 'stim_cor', 'P5_S2_D01_Pos', 0, 'connect')
P5_S2_D10_Bsl_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S2_D10_Bsl_preprocessed_epo.fif')
SourcesReco(P5_S2_D10_Bsl_epx, 'stim_cor', 'P5_S2_D10_Bsl', 0, 'connect')
P5_S2_D10_Pos_epx = mne.read_epochs('../../../Documents/Preprocessed/Patients/P5_S2_D10_Pos_preprocessed_epo.fif')
SourcesReco(P5_S2_D10_Pos_epx, 'stim_cor', 'P5_S2_D10_Pos', 0, 'connect')
# Out:
# Reading ../../../Documents/Preprocessed/Patients/P1_S1_D01_Bsl_preprocessed_epo.fif ...
#     Found the data of interest:
#         t =   -1500.00 ...    1496.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 143 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Created an SSP operator (subspace dimension = 1)
# 1 projection items activated
# SSP projectors applied...
# Computing rank from data with rank=None
#     Using tolerance 1.9e-11 (2.2e-16 eps * 64 dim * 1.3e+03  max singular value)
#     Estimated rank (eeg): 63
#     EEG: rank 63 computed from 64 data channels with 1 projector
#     Created an SSP operator (subspace dimension = 1)
#     Setting small EEG eigenvalues to zero (without PCA)
# ...

# %%
import numpy as np
# Times of interest
min_time = -1.5
max_time = 1.5
num_time = 750
timex = np.linspace(min_time, max_time, num_time)

# Frequency Parameters
min_freq = 2
max_freq = 42
num_freq = 40
frex = np.linspace(min_freq, max_freq, num_freq)

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib.ticker import MaxNLocator

Bsl = np.load('../../../Documents/4th_Results/Pwr_Src/Pwr_P4_S2_D01_Bsl_0.npy') 
Pos = np.load('../../../Documents/4th_Results/Pwr_Src/Pwr_P4_S2_D10_Pos_0.npy')

# Subtraction of spectrums
Dif = Pos - Bsl

# Plotting Power
vmin = -10
vmax = 10
levels = MaxNLocator(nbins=60).tick_values(vmin, vmax)
levels1 = MaxNLocator(nbins=60).tick_values(-5, 5)

fig1 = plt.figure(figsize=(15, 13))
# fig1.set_size_inches(1080,936)

ax1 = fig1.add_subplot(3,1,1)
CS_1 = plt.contourf(timex[350:550], frex, Bsl[:,350:550], cmap='RdBu_r', levels=levels, extend='both')
cbar_1 = fig1.colorbar(CS_1, ax=ax1)
ax1.set_title('Pre')
#ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Frequency (Hz)')

ax2 = fig1.add_subplot(3,1,2)
CS_2 = plt.contourf(timex[350:550], frex, Pos[:,350:550], cmap='RdBu_r', levels=levels, extend='both')
cbar_2 = fig1.colorbar(CS_2, ax=ax2)
ax2.set_title('Post')
#ax2.set_xlabel('Time (s)')
ax2.set_ylabel('Frequency (Hz)')

ax3 = fig1.add_subplot(3,1,3)
CS_3 = plt.contourf(timex[350:550], frex, Dif[:,350:550], cmap='RdBu_r', levels=levels1, extend='both')
cbar = fig1.colorbar(CS_3, ax=ax3)
ax3.set_title('Difference Post - Pre')
ax3.set_xlabel('Time (s)')
ax3.set_ylabel('Frequency (Hz)')

fig1.savefig('Src_TF_%s_%s' %('P4_S2_D01_D10', 'Pos_Bsl'))

# %%
def plot_tf (G1, G2, timex, frex, name):

    diffmap = np.subtract(G2,G1)

    vmax=0.3
    vmin=0
    levels = MaxNLocator(nbins=60).tick_values(vmin, vmax)
    levels1 = MaxNLocator(nbins=60).tick_values(-0.3, 0.3)

    fig1 = plt.figure(figsize=(15.0, 13.0))

    ax1 = fig1.add_subplot(3,1,1)
    CS_1 = plt.contourf(timex[350:550], frex, G1[:,350:550], cmap='RdBu_r', levels=levels, extend='both')
    cbar_1 = fig1.colorbar(CS_1, ax=ax1)
    ax1.set_title('Pre')
    #ax1.set_xlabel('Time (s)')
    ax1.set_ylabel('Frequency (Hz)')

    ax2 = fig1.add_subplot(3,1,2)
    CS_2 = plt.contourf(timex[350:550], frex, G2[:,350:550], cmap='RdBu_r', levels=levels, extend='both')
    cbar_2 = fig1.colorbar(CS_2, ax=ax2)
    ax2.set_title('Post')
    #ax2.set_xlabel('Time (s)')
    ax2.set_ylabel('Frequency (Hz)')

    ax3 = fig1.add_subplot(3,1,3)
    CS_3 = plt.contourf(timex[350:550], frex, diffmap[:,350:550], cmap='RdBu_r', levels=levels1, extend='both')
    cbar = fig1.colorbar(CS_3, ax=ax3)
    ax3.set_title('Difference Post - Pre')
    ax3.set_xlabel('Time (s)')
    ax3.set_ylabel('Frequency (Hz)')

#             plt.show()
    fig1.savefig('%s' %name)

Bsl = np.load('../../../Documents/4th_Results/Wpli_Src/WPLI_P5_S2_D01_Bsl_0.npy')
Pos = np.load('../../../Documents/4th_Results/Wpli_Src/WPLI_P5_S2_D10_Pos_0.npy') 
    
for b in range(2):
    for c in range(b):
        plot_tf(Bsl[b,c,:,:], Pos[b,c,:,:], timex, frex, 'Src_Wpli_P5_S2_D01_D10_%s%s' %(b,c))
